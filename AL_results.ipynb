# %%
import pandas as pd

legal_confidence = pd.read_csv("AL_results/ALResult_Legal_confidence.csv")
legal_margin = pd.read_csv("AL_results/ALResult_Legal_margin.csv")
legal_random = pd.read_csv("AL_results/ALResult_Legal_random.csv")


legal_confidence
# Out:
#     Unnamed: 0      Loss  Accuracy        f1  number_of_samples  \
# 0            0  0.014974  0.929334  0.894845               1690
# 1            1  0.013030  0.936669  0.894845               1690
# 2            2  0.010525  0.948472  0.894845               1690
# 3            3  0.009708  0.952736  0.894845               1690
# 4            4  0.008058  0.961225  0.894845               1690
# 5            5  0.007783  0.966314  0.894845               1690
# 6            6  0.007583  0.964667  0.894845               1690
# 7            7  0.007706  0.966841  0.894845               1690
# 8            8  0.007131  0.966402  0.894845               1690
# 9            9  0.007182  0.966296  0.894845               1690
# 10          10  0.007255  0.959653  0.894845               1690
# 11          11  0.005299  0.974726  0.894845               1690
# 12          12  0.005547  0.968997  0.894845               1690
# 13          13  0.006044  0.969386  0.894845               1690
# ...
